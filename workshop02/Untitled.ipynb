# %%
def crawler_news():
    from selenium import webdriver
    from bs4 import BeautifulSoup
    driver = webdriver.Chrome('chromedriver')
    url = "https://news.naver.com"
    driver.get(url)
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    news_headers = soup.select("ul.mlist2")
    
    print(news_headers)

# %%
crawler_news()
# Out:
# [<ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','88000108_000000000000000003729248', 'airsGParam', '0', 'news_sec_v2.0', 'Qmf7U0BLUem5vtQ9')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0000810243">
# <strong>통합당 김종인호 쇄신 닻 올린다…'기한 · 권한' 놓고 반발 계속</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">SBS</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000108_000000000000000003729248', 'airsGParam', '0', 'news_sec_v2.0', 'Qmf7U0BLUem5vtQ9')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0004667435">
# <strong>어기구에 오거돈까지…'총선 압승' 민주당, 막말·성추행 악재 잇따라</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000108_000000000000000003729248', 'airsGParam', '0', 'news_sec_v2.0', 'Qmf7U0BLUem5vtQ9')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=021&amp;aid=0002425745">
# <strong>“자멸 반성 없이 적당히 비대위에 맡겨…국민 ‘변화 없네’ 느낀다면 정말 소멸”</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">문화일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000108_000000000000000003729248', 'airsGParam', '0', 'news_sec_v2.0', 'Qmf7U0BLUem5vtQ9')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=586&amp;aid=0000013268">
# <strong>수사 확대·제명 추진…위기의 오거돈 '행방묘연'</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">시사저널</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000108_000000000000000003729248', 'airsGParam', '0', 'news_sec_v2.0', 'Qmf7U0BLUem5vtQ9')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=449&amp;aid=0000190680">
# <strong>총선 이후 발표한 오거돈…민주, 직권조사</strong>
# </a>
# <span class="writing">채널A</span>
# </li>
# </ul>, <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425619', 'airsGParam', '0', 'news_sec_v2.0', 'WM1sCi4QnHojQhh6')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0004627081">
# <strong>"이종필이 횡령 시켰다"…상장사 리드 회장 징역 8년</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">이데일리</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425619', 'airsGParam', '0', 'news_sec_v2.0', 'WM1sCi4QnHojQhh6')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=015&amp;aid=0004330166">
# <strong>아파트 세입자도 동대표된다…집주인 후보자 없는 경우만</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한국경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425619', 'airsGParam', '0', 'news_sec_v2.0', 'WM1sCi4QnHojQhh6')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=055&amp;aid=0000810245">
# <strong>'사무실부터 음식점까지'…정부, 생활 속 거리 두기 세부지침 공개</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">SBS</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425619', 'airsGParam', '0', 'news_sec_v2.0', 'WM1sCi4QnHojQhh6')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=586&amp;aid=0000013269">
# <strong>트럼프 "김정은 위중한 상태? CNN 보도는 허위"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">시사저널</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425619', 'airsGParam', '0', 'news_sec_v2.0', 'WM1sCi4QnHojQhh6')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=056&amp;aid=0010824821">
# <strong>‘편법증여·규제 회피’ 1인·가족 부동산 법인 전수 검증</strong>
# </a>
# <span class="writing">KBS</span>
# </li>
# </ul>, <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425620', 'airsGParam', '0', 'news_sec_v2.0', 'p0asaCnfQyQB7WIh')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=277&amp;aid=0004667438">
# <strong>부산 남해고속도로 차 안에서 50대 운전자 숨진채 발견</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425620', 'airsGParam', '0', 'news_sec_v2.0', 'p0asaCnfQyQB7WIh')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0011569557">
# <strong>"자가격리 위반자, 27일부터 안심밴드 착용…미동의시 시설격리"(종합)</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">연합뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425620', 'airsGParam', '0', 'news_sec_v2.0', 'p0asaCnfQyQB7WIh')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=056&amp;aid=0010824834">
# <strong>황금연휴 제주 관광객 18만 명 예상…“여행 자제 부탁”</strong>
# </a>
# <span class="writing">KBS</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425620', 'airsGParam', '0', 'news_sec_v2.0', 'p0asaCnfQyQB7WIh')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=020&amp;aid=0003282817">
# <strong>軍, ‘박사방’ 조주빈 공범 일병 신상 공개 여부 다음주 결정</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">동아일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','08138262_000000000000000000425620', 'airsGParam', '0', 'news_sec_v2.0', 'p0asaCnfQyQB7WIh')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=055&amp;aid=0000810244">
# <strong>학교 99% 이상 '등교 방역' 준비 완료…"시기는 협의 중"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">SBS</span>
# </li>
# </ul>, <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000535257', 'airsGParam', '0', 'news_sec_v2.0', 'iyD4GlctX3PHAM0L')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=015&amp;aid=0004330134">
# <strong>골프장 갔다가 원인 미상으로 쓰러진 여성 머리서 탄두 발견</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">한국경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000535257', 'airsGParam', '0', 'news_sec_v2.0', 'iyD4GlctX3PHAM0L')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=052&amp;aid=0001432159">
# <strong>[오뉴스] "상처 연고! 개봉 후 6개월 지나면 효과 떨어져"...우리집 비상약 관리법</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">YTN</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000535257', 'airsGParam', '0', 'news_sec_v2.0', 'iyD4GlctX3PHAM0L')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=031&amp;aid=0000535706">
# <strong>49초만에 매진 걱정 끝! 조성진 리사이틀 26일 밤 11시 유튜브 생중계로 본다</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아이뉴스24</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000535257', 'airsGParam', '0', 'news_sec_v2.0', 'iyD4GlctX3PHAM0L')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=031&amp;aid=0000535705">
# <strong>"우리집을 신고해주세요"…'궁금한 이야기Y' SNS 사칭범 정체는?</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아이뉴스24</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000535257', 'airsGParam', '0', 'news_sec_v2.0', 'iyD4GlctX3PHAM0L')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=057&amp;aid=0001447834">
# <strong>서울 명동성당 등 미사 재개…"아직 이르다" 우려도</strong>
# </a>
# <span class="writing">MBN</span>
# </li>
# </ul>, <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001432173', 'airsGParam', '0', 'news_sec_v2.0', 'OCcz20YrmGicjFcP')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=003&amp;aid=0009832851">
# <strong>전화 먹통, 한달째 수령 불가…'분노 유발' 美 실업수당</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴시스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001432173', 'airsGParam', '0', 'news_sec_v2.0', 'OCcz20YrmGicjFcP')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=277&amp;aid=0004667428">
# <strong>'코로나19' 치료제로 주목받던 렘데시비르 임상 효과 없어…시장 후폭풍</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001432173', 'airsGParam', '0', 'news_sec_v2.0', 'OCcz20YrmGicjFcP')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=422&amp;aid=0000425604">
# <strong>중남미서도 봉쇄 완화 시작…가파른 확산세에 우려도</strong>
# </a>
# <span class="writing">연합뉴스TV</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001432173', 'airsGParam', '0', 'news_sec_v2.0', 'OCcz20YrmGicjFcP')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=056&amp;aid=0010824807">
# <strong>“김정은 위중 CNN 보도 부정확…오래된 서류 인용”</strong>
# </a>
# <span class="writing">KBS</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AF_000000000000000001432173', 'airsGParam', '0', 'news_sec_v2.0', 'OCcz20YrmGicjFcP')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=422&amp;aid=0000425602">
# <strong>美주정부 '한국산 진단키트' 앞다퉈 확보</strong>
# </a>
# <span class="writing">연합뉴스TV</span>
# </li>
# </ul>, <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000AC_000000000000000002085304', 'airsGParam', '0', 'news_sec_v2.0', 'rt0Kp43wSgS0Ga08')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=417&amp;aid=0000535249">
# <strong>넷플릭스가 포켓몬을 독점공개한다고?… 애니메이션 강화</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">머니S</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AC_000000000000000002085304', 'airsGParam', '0', 'news_sec_v2.0', 'rt0Kp43wSgS0Ga08')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=421&amp;aid=0004605009">
# <strong>"나 때는 말이야" 대신 "잘 해줘"…카카오 김범수의 리더십</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴스1</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AC_000000000000000002085304', 'airsGParam', '0', 'news_sec_v2.0', 'rt0Kp43wSgS0Ga08')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=092&amp;aid=0002187025">
# <strong>“3세대 에어팟, 내년에 나온다”</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">ZDNet Korea</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AC_000000000000000002085304', 'airsGParam', '0', 'news_sec_v2.0', 'rt0Kp43wSgS0Ga08')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=092&amp;aid=0002187021">
# <strong>라이엇게임즈 MSI 취소...e스포츠까지 강타한 코로나19</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">ZDNet Korea</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000AC_000000000000000002085304', 'airsGParam', '0', 'news_sec_v2.0', 'rt0Kp43wSgS0Ga08')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=277&amp;aid=0004667373">
# <strong>얼굴 인식 0.3초…"바라만 봐도 식사 결제 끝"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# </ul>]
